# %%
import numpy as np
import numpy.random as nr
from numpy.linalg import matrix_rank
from numpy.linalg import inv

import scipy 
import scipy.stats as stats
from scipy.special import softmax, logit, expit
from scipy.linalg import eigh
from scipy.linalg import sqrtm

import matplotlib.pyplot as plt

import sklearn
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import sys
sys.path.append("../src")
from graph import Graph, create_clustered_graph
from graph_clustering import cluster_graph

# %%
K = 4
N = 10
G = create_clustered_graph(K = K, N= N)
cluster = cluster_graph(G,K = K)
# Out:
# Number of clusters: 4
# c:\Users\arthu\anaconda3\envs\DL_env\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\arthu\anaconda3\envs\DL_env\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
